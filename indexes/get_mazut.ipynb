# %%
library(tabulizer)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# Location of WARN notice pdf file
location <- 'http://www.kortes.com/products/pdf/reg.pdf'

# Extract the table
out <- extract_tables(location, method="stream")

# %%
out[[1]]
# Out:
#       [,1]
#  [1,] Область, край,
#  [2,] республика
#  [3,]
#  [4,] Архангельская область
#  [5,]
#  [6,] Вологодская область
#  [7,]
#  [8,] Ленинградская область
#  [9,]
# [10,] Мурманская область
# [11,]
# [12,] Республика Карелия
# [13,]
# [14,] Республика Коми
# [15,]
# [16,]
# [17,] Белгородская область
# [18,]
# [19,] Брянская область
# [20,]
# [21,] Владимирская область
# [22,]
# [23,] Воронежская область
# [24,]
# [25,] Костромская область
# [26,]
# [27,] Курская область
# [28,]
# [29,] Липецкая область
# [30,]
# [31,] Московская область
# [32,]
# [33,] Орловская область
# [34,]
# [35,] Смоленская область
# [36,]
# [37,] Тамбовская область
# [38,]
# [39,] Тверская область
# [40,]
# [41,] Тульская область
# [42,]
# [43,]
# [44,] Нижегородская область
# [45,]
# [46,] Оренбургская область
# [47,]
# [48,] Пензенская область
# [49,]
#       [,2]                                                    [,3]
#  [1,] Автомобильный бензин Дизтопливо
# ...

# %%
write.csv(out[[1]], file = 'mazut_tmp_1.csv')

# %%
write.csv(out[[2]], file = 'mazut_tmp_2.csv')

# %%
out[[2]]
# Out:
#       [,1]
#  [1,] Область, край,\rреспублика
#  [2,] Нормаль-80
#  [3,] Пермский край29100 - 2930031400 - 3160032800 - 3300035200 - 35400\r10200 - 10400\r+600
#  [4,] Республика Башкортостан28000 - 2820030800 - 3100031800 - 3200033500 - 33700\r6600 - 6800
#  [5,] Республика Татарстан29100 - 2930031300 - 3150033400 - 3360034500 - 34700\r7600 - 7800\r+200-300
#  [6,] Самарская область\r30900 - 3110032300 - 3250034200 - 3440028900 - 291009500 - 9700\r+400
#  [7,] Саратовская область\r31100 - 3130032600 - 3280034000 - 3420029700 - 299009500 - 9700\r+300+1000-600
#  [8,] Ульяновская область\r31100 - 3130032300 - 3250034200 - 34400\r8300 - 8500\r+300+800-200
#  [9,] ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ ОКРУГ
# [10,] Астраханская область30000 - 3020031700 - 3190033100 - 33300\r29300 - 295009500 - 9700\r+600+900
# [11,] Волгоградская область\r31400 - 3160032900 - 3310034400 - 3460031300 - 315009800 - 10000\r+600+500
# ...

# %%
# Location of WARN notice pdf file
location <- '/home/xenakas/Desktop/job_job/indexes/prices_gas_data/fst_pred/prikaz_fas_1088-18_ot_2018.08.03.pdf'

# Extract the table
out <- extract_tables(location)

# %%
out
# Out:
# list()
