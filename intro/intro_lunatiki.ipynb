# %% [markdown]
# # Код в Python

# %% [markdown]
# $\LaTeX $ в Markdown  $$ \int_0^\infty \sin(x)\cos(x)dx $$

# %%
a = [1,2,3]
b = [4,5,6]
a+b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
import numpy as np
a = np.array(a)
a*b
# Out:
# array([ 4, 10, 18])

# %%
third = second.copy()
third.append(7)
third
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a = [5,3,4,2,1]
a.sort()
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a = [5,3,4,2,1]
b = sorted(a)
b
# Out:
# [1, 2, 3, 4, 5]

# %%
s = [3,3,2,1,2,4,1,5]
s1 = list(set(s)) #сортироваь множества нельзя
s1.sort()
s1
# Out:
# [1, 2, 3, 4, 5]

# %%
type(s1)
# Out:
# list

# %%
dd = { 0: '', 1: '', 2: 'Двадцать', 3: 'Тридцать', 4: 'Сорок', 5: 'Пятьдесят', 6: 'Шестьдесят', 7: 'Семьдесят', 8: 'Восемьдесят', 9: 'Девяносто'}

ddd = { 0: 'Десять',  1: 'Одиннадцать' ,  2: 'Двенадцать',  3: 'Тринадцать',  4: 'Четырандцать',  5: 'Пятнадцать',  6: 'Шестнадцать',  7: 'Семнадцать',  8: 'Восемнадцать',  9: 'Девятнадцать'}

d = { 0: 'Один', 1: 'Два', 2: 'Три', 3: 'Четыре', 4: 'Пять', 5: 'Шесть', 6: 'Семь', 7: 'Восемь', 8: 'Девять', 9: 'Десять' }

ka = [1, 2, 3]
kov = [4, 5, 6, 7, 8]

# %%
story = "И больше лунатиков не стало на Луне! "

for j in range(10):
    if j == 0:
        for i in range(9):
            if i in kov: 
                lun = "лунатиков "
                live = "жили "
                vor = "ворочались "
                ost = "осталось "
            elif i in ka:       
                lun = "лунатика "
                live = "жили "
                vor = "ворочались "
                ost = "осталось "
            else: 
                lun = "лунатик "
                live = "жил "
                vor = "ворочался "
                ost = "остался "
            story =  "И " +  d[i].lower() + " " + lun + ost + "на Луне. \n \n" +  d[i] + " " + lun  + live + "на Луне, \n" +  d[i] + " " +  lun  + vor + "во сне, \n" + "И вдруг один лунатик упал с Луны во сне \n"  + story 
    if j == 1:
        for i in range(9):
            lun = "лунатиков "
            story =  "И " +  ddd[i].lower() + " " + lun + ost + "на Луне. \n \n" +  ddd[i] + " " + lun  + "жили на Луне, \n" +  ddd[i] + " " +  lun  + "ворочались во сне, \n" + "И вдруг один лунатик упал с Луны во сне \n"  + story 
    if j > 1:
        for i in range(9):
            if i in kov: 
                lun = "лунатиков "
                live = "жили "
                vor = "ворочались "
                ost = "осталось "
            elif i in ka:       
                lun = "лунатика "
                live = "жили "
                vor = "ворочались "
                ost = "осталось "
            else: 
                lun = "лунатик "
                live = "жил "
                vor = "ворочался "
                ost = "остался "
            story =  "И " +  dd[j].lower()  + " " +  d[i].lower() + " " + lun +  ost +  "на Луне. \n \n" +  dd[j]   + " "  + d[i].lower() + " " + lun  + live + "на Луне, \n" +  dd[j]   + " " + d[i].lower() + " " +  lun  + vor + "во сне, \n" + "И вдруг один лунатик упал с Луны во сне \n"  + story 

story = "Сто лунатиков жили на Луне, \n" +  "Сто лунатиков ворочались во сне, \n" + "И вдруг один лунатик упал с Луны во сне \n"  + story  
        
print(story)
# Out:
# Сто лунатиков жили на Луне,
# Сто лунатиков ворочались во сне,
# И вдруг один лунатик упал с Луны во сне
# И девяносто девять лунатиков осталось на Луне.
#
# Девяносто девять лунатиков жили на Луне,
# Девяносто девять лунатиков ворочались во сне,
# И вдруг один лунатик упал с Луны во сне
# И девяносто восемь лунатиков осталось на Луне.
#
# Девяносто восемь лунатиков жили на Луне,
# Девяносто восемь лунатиков ворочались во сне,
# И вдруг один лунатик упал с Луны во сне
# И девяносто семь лунатиков осталось на Луне.
#
# Девяносто семь лунатиков жили на Луне,
# Девяносто семь лунатиков ворочались во сне,
# И вдруг один лунатик упал с Луны во сне
# И девяносто шесть лунатиков осталось на Луне.
#
# Девяносто шесть лунатиков жили на Луне,
# Девяносто шесть лунатиков ворочались во сне,
# И вдруг один лунатик упал с Луны во сне
# И девяносто пять лунатиков осталось на Луне.
#
# Девяносто пять лунатиков жили на Луне,
# Девяносто пять лунатиков ворочались во сне,
# ...
