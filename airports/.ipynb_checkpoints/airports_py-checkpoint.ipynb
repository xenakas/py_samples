# %% [markdown]
# # Airports

# %%
import numpy as np
import pandas as pd

# %%
airports = pd.read_csv('airports.csv',names = ['Airport ID','Name','City','Country','IATA','ICAO','Latitude','Longitude','Altitude','Timezone','DST','Tz_database_time_zone','Type','Source'])
routes = pd.read_csv('routes.csv',names = ['Airline','Airport ID','Source airport','Source airport ID','Destination airport','Destination airport ID','Codeshare','Stops','Equipment'])
airlines = pd.read_csv('airlines.csv',names = ['Airline ID','Name','Alias','IATA','ICAO','Callsign','Country','Active'])

# %% [markdown]
# ### Task 1

# %%
airports.count()
# Out:
# Airport ID               7184
# Name                     7184
# City                     7140
# Country                  7184
# IATA                     7182
# ICAO                     7184
# Latitude                 7184
# Longitude                7184
# Altitude                 7184
# Timezone                 7184
# DST                      7184
# Tz_database_time_zone    7184
# Type                     7184
# Source                   7184
# dtype: int64

# %%
pd.Series(airports[airports['City'].str.len()<=3]['City'].unique()).sort_values()
# Out:
# 43    Ada
# 29    Ahe
# 24    Ann
# 30    Bam
# 27     Bo
# 41    Bor
# 28    Diu
# 35    Eek
# 34    Ely
# 5     Fes
# 4     Gao
# 19    Goa
# 3     Hof
# 6     Hon
# 23    Hue
# 47     Ie
# 14    Iki
# 16    Ilo
# 32    Imo
# 2     Jos
# 45    Kao
# 22    Kep
# 8     Kos
# 31    Lar
# 20    Leh
# 1     Man
# 11    Moa
# 33    Mus
# 25    Nan
# 10    Nis
# 17    Osh
# 46    Ota
# 15    Otu
# 26    Pai
# 7     Pau
# 42    Spa
# 12    Sui
# 21    Tak
# 36    Tok
# 18    Ufa
# 39    Una
# 44    Uyo
# 9     Van
# 0      Wa
# 40    Wau
# 13    Yap
# 38     Ye
# 37    Yei
# dtype: object

# %%
airports['City'].isnull().sum()
# Out:
# 44

# %%
airports[airports['Country'] == '\\N']
# Out:
# Empty DataFrame
# Columns: [Airport ID, Name, City, Country, IATA, ICAO, Latitude, Longitude, Altitude, Timezone, DST, Tz_database_time_zone, Type, Source]
# Index: []

# %%
airports[airports['DST'] == 'E']['Country'].unique()
# Out:
# array(['Greenland', 'Tunisia', 'Belgium', 'Germany', 'Estonia', 'Finland',
#        'United Kingdom', 'Guernsey', 'Jersey', 'Isle of Man',
#        'Netherlands', 'Ireland', 'Denmark', 'Faroe Islands', 'Luxembourg',
#        'Norway', 'Poland', 'Sweden', 'Spain', 'Albania', 'Bulgaria',
#        'Cyprus', 'Croatia', 'France', 'Greece', 'Hungary', 'Italy',
#        'Slovenia', 'Czech Republic', 'Israel', 'Malta', 'Austria',
#        'Portugal', 'Bosnia and Herzegovina', 'Romania', 'Switzerland',
#        'Turkey', 'Moldova', 'Macedonia', 'Serbia', 'Montenegro',
#        'Slovakia', 'Iran', 'Jordan', 'Lebanon', 'Syria', 'Azerbaijan',
#        'Ukraine', 'Belarus', 'Latvia', 'Lithuania', 'Armenia',
#        'Uzbekistan', 'Kyrgyzstan', 'Egypt', 'Iceland', 'Reunion',
#        'Morocco', 'United States', 'Guinea'], dtype=object)

# %%
airports[airports['Tz_database_time_zone'].str.contains("Europe")]['Country'].unique()
# Out:
# array(['Belgium', 'Germany', 'Estonia', 'Finland', 'United Kingdom',
#        'Guernsey', 'Jersey', 'Isle of Man', 'Netherlands', 'Ireland',
#        'Denmark', 'Luxembourg', 'Norway', 'Poland', 'Sweden', 'Spain',
#        'Albania', 'Bulgaria', 'Cyprus', 'Croatia', 'France', 'Greece',
#        'Hungary', 'Italy', 'Slovenia', 'Czech Republic', 'Malta',
#        'Austria', 'Portugal', 'Bosnia and Herzegovina', 'Romania',
#        'Switzerland', 'Turkey', 'Moldova', 'Macedonia', 'Gibraltar',
#        'Serbia', 'Montenegro', 'Slovakia', 'Ukraine', 'Russia', 'Belarus',
#        'Latvia', 'Lithuania', 'United States'], dtype=object)

# %%
df_a = airports[airports['Tz_database_time_zone'].str.contains("Europe") ]

df_a[df_a['Country'] == 'United States']
# Out:
#       Airport ID             Name      City        Country IATA  ICAO  \
# 6489        9403  Taszár Air Base  Columbus  United States  TZR  LHTA
#
#        Latitude  Longitude  Altitude Timezone DST Tz_database_time_zone  \
# 6489  46.393101    17.9175       531        1   A       Europe/Budapest
#
#          Type       Source
# 6489  airport  OurAirports

# %%
euro = np.array(['Belgium', 'Germany', 'Estonia', 'Finland', 'United Kingdom', 
'Guernsey', 'Jersey', 'Isle of Man', 'Netherlands', 'Ireland', 
'Denmark', 'Luxembourg', 'Norway', 'Poland', 'Sweden', 'Spain', 
'Albania', 'Bulgaria', 'Cyprus', 'Croatia', 'France', 'Greece', 
'Hungary', 'Italy', 'Slovenia', 'Czech Republic', 'Malta', 
'Austria', 'Portugal', 'Bosnia and Herzegovina', 'Romania', 
'Switzerland', 'Turkey', 'Moldova', 'Macedonia', 'Gibraltar', 
'Serbia', 'Montenegro', 'Slovakia', 'Ukraine', 'Russia', 'Belarus', 
'Latvia', 'Lithuania', 'Iceland', 'Faroe Islands'])

airports[airports['Country'].isin(euro)]
# Out:
#       Airport ID                                    Name               City  \
# 10            11                        Akureyri Airport           Akureyri
# 11            12                     Egilsstaðir Airport        Egilsstadir
# 12            13                    Hornafjörður Airport               Hofn
# 13            14                         Húsavík Airport            Husavik
# 14            15                      Ísafjörður Airport         Isafjordur
# 15            16          Keflavik International Airport           Keflavik
# 16            17                  Patreksfjörður Airport     Patreksfjordur
# 17            18                       Reykjavik Airport          Reykjavik
# 18            19                    Siglufjörður Airport       Siglufjordur
# 19            20                  Vestmannaeyjar Airport     Vestmannaeyjar
# 296          299  Antwerp International Airport (Deurne)            Antwerp
# ...

# %%
airports = airports.replace('\\N', np.nan)

# %%
airports[airports['ICAO'].str.len() != 4]['ICAO']
# Out:
# 4409    Q51
# 4475    03N
# 4737    5A8
# 4741    KQA
# 4742    S31
# Name: ICAO, dtype: object

# %%
airports[(airports['IATA'].str.len() == 3) & (airports['Country'].isin(euro))].dropna().count()
# Out:
# Airport ID               1020
# Name                     1020
# City                     1020
# Country                  1020
# IATA                     1020
# ICAO                     1020
# Latitude                 1020
# Longitude                1020
# Altitude                 1020
# Timezone                 1020
# DST                      1020
# Tz_database_time_zone    1020
# Type                     1020
# Source                   1020
# dtype: int64

# %% [markdown]
# ### Task 2

# %%
airports[airports['Altitude'] >= 14000]['IATA']
# Out:
# 5000    BPX
# 5819    NGQ
# Name: IATA, dtype: object

# %%
ports = routes[(routes['Source airport']=='BPX')|(routes['Source airport']=='NGQ')|(routes['Destination airport']=='NGQ')|(routes['Destination airport']=='NGQ')]
ports = np.unique(ports.Airline.values)
ports
# Out:
# array(['CA', 'MU', 'TV', 'ZH'], dtype=object)

# %%
np.array([airlines[airlines['IATA']==i]['Name'].values for i in ports ]).T
# Out:
# array([['Air China', 'China Eastern Airlines', 'Virgin Express',
#         'Shenzhen Airlines']], dtype=object)
